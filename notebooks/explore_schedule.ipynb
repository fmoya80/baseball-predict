# %%
import pandas as pd

# %%
df[df['home_team_abbreviation'] == 'NYY']
# Out:
#      game_date  gamePk game_type  season         game_datetime  \
# 54  2026-04-05  823566         R    2026  2026-04-05T17:35:00Z
# 55  2026-04-07  823567         R    2026  2026-04-07T23:05:00Z
# 56  2026-04-03  823568         R    2026  2026-04-03T17:35:00Z
# 57  2026-04-04  823569         R    2026  2026-04-04T23:05:00Z
#
#    status_abstract_game_state status_abstract_game_code status_detailed_state  \
# 54                      Final                         F                 Final
# 55                      Final                         F                 Final
# 56                      Final                         F                 Final
# 57                      Final                         F                 Final
#
#    status_coded_game_state status_status_code  ...  \
# 54                       F                  F  ...
# 55                       F                  F  ...
# 56                       F                  F  ...
# ...

# %%
df = pd.read_parquet(r"C:\Users\felip\OneDrive\Belgeler\Pipe\baseball-predict\data\processed\pregame_features_master.parquet")

# %%
df.columns
# Out:
# Index(['game_date', 'gamePk', 'game_type', 'season', 'game_datetime',
#        'status_abstract_game_state', 'status_abstract_game_code',
#        'status_detailed_state', 'status_coded_game_state',
#        'status_status_code',
#        ...
#        'home_offense_iso_game_season_to_date',
#        'home_offense_context_found_flag', 'away_offense_has_last_3_data_flag',
#        'away_offense_has_last_5_data_flag',
#        'home_offense_has_last_3_data_flag',
#        'home_offense_has_last_5_data_flag', 'away_starter_era_last_3',
#        'away_starter_era_last_5', 'home_starter_era_last_3',
#        'home_starter_era_last_5'],
#       dtype='object', length=220)
